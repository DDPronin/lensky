# %% [markdown]
# **Пример исследования: изучение средней тональности произведений по годам**

# %% [markdown]
# Импорт Lensky и требуемых библиотек

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt

# %%
df = pd.read_excel('data/RuLitStat.xlsx')
df
# Out:
#                                         filename                         book  \
# 0                       Авдеев.Варенька.1852.txt                     Варенька
# 1                         Авдеев.Иванов.1852.txt                       Иванов
# 2    Авдеев.Тетрадь_из_записок_Тамарина.1852.txt  Тетрадь_из_записок_Тамарина
# 3                    Авенариус.Поветрие.1867.txt                     Поветрие
# 4         Авенариус.Современная_идиллия.1867.txt          Современная_идиллия
# ..                                           ...                          ...
# 750                    Ясинский.Верочка.1887.txt                      Верочка
# 751                    Ясинский.Учитель.1888.txt                      Учитель
# 752                      Яхина.Дети_мои.2018.txt                     Дети_мои
# 753       Яхина.Зулейха_открывает_глаза.2015.txt      Зулейха_открывает_глаза
# 754           Яхина.Эшелон_до_Самарканд.2021.txt          Эшелон_до_Самарканд
#
#         author  year  cent     len  len_unique  uniq_words_not_in_pop  \
# 0       Авдеев  1852    19  152668        6555                    469
# 1       Авдеев  1852    19  170248        7549                    494
# 2       Авдеев  1852    19  154196        6731                    491
# 3    Авенариус  1867    19  256336       12694                    705
# 4    Авенариус  1867    19  305536       13909                    923
# ..         ...   ...   ...     ...         ...                    ...
# 750   Ясинский  1887    19  119630        6392                    348
# 751   Ясинский  1888    19  121856        6295                    375
# 752      Яхина  2018    21  780736       31275                   2996
# 753      Яхина  2015    21  712961       27269                   2767
# 754      Яхина  2021    21  768570       29617                   2828
#
#      mean_freq1k  dost_neu  ...      NOUN       NUM      PART      PRON  \
# 0     759.008835  0.439804  ...  0.164474  0.006164  0.055597  0.146570
# 1     702.438997  0.459784  ...  0.179738  0.007481  0.047394  0.118560
# 2     744.420935  0.415810  ...  0.168965  0.006130  0.047310  0.149082
# 3     747.801066  0.489591  ...  0.211074  0.007128  0.058478  0.110938
# 4     748.249222  0.535464  ...  0.196245  0.007834  0.060576  0.103942
# ..           ...       ...  ...       ...       ...       ...       ...
# 750   749.065562  0.445304  ...  0.197364  0.006226  0.040210  0.136920
# 751   795.539469  0.487984  ...  0.198243  0.005270  0.042263  0.131646
# 752   737.782698  0.447696  ...  0.275472  0.007331  0.039981  0.041392
# 753   699.971191  0.503221  ...  0.267870  0.008460  0.037172  0.049176
# 754   692.096807  0.486496  ...  0.252319  0.009059  0.052235  0.048428
#
#         PROPN     PUNCT     SCONJ       SYM      VERB         X
# 0    0.048569  0.264046  0.030311  0.000000  0.167576  0.003809
# 1    0.041129  0.246628  0.028709  0.000000  0.164996  0.000663
# 2    0.033086  0.250108  0.031514  0.000039  0.166451  0.000825
# 3    0.035516  0.311703  0.022050  0.000000  0.157011  0.009298
# 4    0.036025  0.319947  0.027060  0.000000  0.157280  0.019945
# ..        ...       ...       ...       ...       ...       ...
# 750  0.037823  0.283958  0.025112  0.000000  0.178842  0.001608
# 751  0.057556  0.263136  0.026608  0.000000  0.179695  0.000258
# 752  0.037842  0.239701  0.018335  0.000000  0.156017  0.000793
# 753  0.042556  0.287307  0.016902  0.000000  0.164584  0.001254
# 754  0.037573  0.274621  0.018526  0.000008  0.157203  0.000473
#
# [755 rows x 35 columns]

# %% [markdown]
# Возьмем нужные столбцы

# %%
cols = ['year', 'dost_neg', 'dost_pos']
df = df[cols].sort_values(by='year')
df
# Out:
#      year  dost_neg  dost_pos
# 700  1782  0.097513  0.054868
# 533  1790  0.152137  0.044189
# 272  1792  0.097750  0.119606
# 271  1792  0.141277  0.124906
# 273  1802  0.137417  0.083253
# ..    ...       ...       ...
# 464  2022  0.138012  0.054655
# 565  2022  0.154550  0.035621
# 608  2022  0.114538  0.071756
# 262  2023  0.123399  0.033623
# 135  2023  0.130233  0.042390
#
# [755 rows x 3 columns]

# %% [markdown]
# Вычислим тональность как разность позитивной и негатичной лексики

# %%
df['ton'] = df['dost_pos']-df['dost_neg']
df = df.drop(['dost_pos', 'dost_neg'], axis=1)
df
# Out:
#      year       ton
# 700  1782 -0.042645
# 533  1790 -0.107948
# 272  1792  0.021856
# 271  1792 -0.016370
# 273  1802 -0.054163
# ..    ...       ...
# 464  2022 -0.083357
# 565  2022 -0.118929
# 608  2022 -0.042782
# 262  2023 -0.089776
# 135  2023 -0.087843
#
# [755 rows x 2 columns]

# %% [markdown]
# Построим промежутки для подсчета среднего

# %%
years = list(range(1800, 2041, 20))
years
# Out:
# [1800, 1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960, 1980, 2000, 2020, 2040]

# %%
tons = []
quant = []
for i in range(1, len(years)):
    res = df[(df['year'] > years[i-1]) & (df['year'] < years[i])]['ton']
    quant.append(len(res))
    tons.append(res.mean())

# %% [markdown]
# Средние тональности

# %%
tons
# Out:
# [-0.05184465441656822,
#  -0.07712102851073858,
#  -0.0731312628728962,
#  -0.09077381278864816,
#  -0.08998958679018103,
#  -0.08855355707325793,
#  -0.09344016831853047,
#  -0.09891148745493834,
#  -0.10002484561339255,
#  -0.09319475145401429,
#  -0.09182399455237589,
#  -0.08447123340872414]

# %% [markdown]
# Количество произведений в каждом отрезке (края не очень статистически надежны, но закономерности в середине списка 1820-2020 могут быть статистически значимы)

# %%
quant
# Out:
# [2, 62, 86, 127, 167, 35, 48, 17, 33, 44, 79, 9]

# %% [markdown]
# Построение графика

# %%
from matplotlib.pyplot import figure
figure(figsize=(10, 6), dpi=100)
plt.plot(tons)
plt.xticks(range(len(years)-1), [f'{years[i-1]}-{years[i]}' for i in range(1, len(years))], rotation=90)
plt.xlabel('Годы')
plt.ylabel('Средняя тональность произведений')
plt.title('Средняя тональность произведений русской литературы по годам')
plt.grid()
