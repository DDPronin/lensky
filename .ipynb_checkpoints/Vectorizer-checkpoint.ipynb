# %%
import os
import tqdm
import numpy as np
import itertools

# %%
DATA_PATH = 'D:\\DDPronin\\PyCharm\\RU Classic Literature graphs\\data\\corpus_ru_normalized'
DATA = os.listdir(DATA_PATH)
DATA
# Out:
# ['Авдеев.Варенька.1852.txt',
#  'Авдеев.Иванов.1852.txt',
#  'Авдеев.Тетрадь_из_записок_Тамарина.1852.txt',
#  'Авенариус.Поветрие.1867.txt',
#  'Авенариус.Современная_идиллия.1867.txt',
#  'Аксаков.Детские_годы_Багрова-внука.1858.txt',
#  'Аксаков.Семейная_хроника.1856.txt',
#  'Алексеев.Игра_судьбы.1913.txt',
#  'Алексеев.Лжецаревич.1898.txt',
#  'Амфитеатров.Отравленная_совесть.1890.txt',
#  'Анненская.Анна.1881.txt',
#  'Анненская.Брат_и_сестра.1908.txt',
#  'Анненская.Волчонок.1889.txt',
#  'Анненская.Младший_брат.1889.txt',
#  'Анненская.Неудачник.1889.txt',
#  'Анненская.Трудная_борьба.1889.txt',
#  'Анненская.Тяжелая_жизнь.1877.txt',
#  'Анненская.Чужой_хлеб.1872.txt',
#  'Апраксин.Ловкачи.1897.txt',
#  'Апухтин.Архив_графини_Д..1895.txt',
#  'Апухтин.Дневник_Павлика_Дольского.1895.txt',
#  'Апухтин.Неоконченная_повесть.1898.txt',
#  'Аскоченский.Асмодей_нашего_времени.1858.txt',
#  'Ахшарумов.Концы_в_воду.1872.txt',
# ...

# %%
AUTHORS = list(set([element.replace('_','.').split('.')[0].lower() for element in DATA]))

# %%
#Функция для считывания книг в словарь
def to_dict(DATA_PATH, BOOKS):
    out_dict = {}
    for name in BOOKS:
        with open(f'{DATA_PATH}\\{name}', encoding="utf-8") as f:
            out_dict[name[:-4]] = ' '.join(f.read().split())
    return out_dict

# %%
# %%time
corpus = {}
data_low = [data.lower() for data in DATA]
for author in tqdm.tqdm(AUTHORS):
    author_books = []
    for i in range(len(data_low)):
        if author in data_low[i]:
            author_books.append(DATA[i])
    corpus[author] = to_dict(DATA_PATH, author_books)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 155/155 [00:04<00:00, 37.24it/s]
# Wall time: 4.17 s

# %%
sent18 = []
sent19 = []
sent20 = []
sent21 = []
keys = corpus.keys()
for key in keys:
    for book in corpus[key].keys():
        year = book.split('.')[-1]
        if year[-1] in [')', ']']:
            year = year[:-1]
        year = int(year)
        if year < 1801:
            sent18.append(book)
        if 1800 < year and year < 1901:
            sent19.append(book)
        if 1900 < year and year < 2001:
            sent20.append(book)
        if year >= 2001:
            sent21.append(book)

# %%
corpus_sent_book = {18 : [], 19 : [], 20 : [], 21 : []}
for key in keys:
     for name in corpus[key].keys():
            if name in sent18:
                corpus_sent_book[18].append(corpus[key][name])
            if name in sent19:
                corpus_sent_book[19].append(corpus[key][name])
            if name in sent20:
                corpus_sent_book[20].append(corpus[key][name])
            if name in sent21:
                corpus_sent_book[21].append(corpus[key][name])

# %%
# {key: [el1, el2...], ...} -> {key: [vec1, vec2...], ...}
def vectorize(corpus, vectorizer):
    keys = list(corpus.keys())
    books = list(itertools.chain.from_iterable(corpus.values())) # {key: [el1, el2...], ...} -> [el1, el2, el3, el4...]
    #Векторизация
    vectorizer = vectorizer.fit(books)
    out = {}
    for key in tqdm.tqdm(keys):
        out[key] = []
        for element in corpus[key]:
            out[key].append(vectorizer.transform([element]).A[0]) # sparse -> numpy
    return out

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()

# %%
# %%time
corpus_sent_book_vecs = vectorize(corpus_sent_book, tfidf)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:10<00:00,  2.60s/it]
# Wall time: 18.2 s

# %%
print(len(corpus_sent_book_vecs[18]))
print(len(corpus_sent_book_vecs[19]))
print(len(corpus_sent_book_vecs[20]))
print(len(corpus_sent_book_vecs[21]))
# Out:
# 3
# 493
# 55
# 13

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

#Функция для отрисовки графиков
# {key: [vec1, vec2...], ...} -> plot
def build_model_plot(corpus, model, legend_title='legend_title', plot_title='plot_title'):
    figure(figsize=(10, 10), dpi=250)
    keys = list(corpus.keys())
    books = list(itertools.chain.from_iterable(corpus.values()))
    model.fit(books)
    for key in keys:
        z_model = model.transform(corpus[key])
        plt.scatter(z_model[:,0], z_model[:, 1], label=key, s=7)
    plt.legend(title=legend_title)
    plt.title(plot_title)
    plt.xticks([])
    plt.yticks([])

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

#Функция для отрисовки графиков
# {key: [vec1, vec2...], ...} -> plot
def build_model_plot(corpus, model, colors, point_size = 10, mass_center = False, 
                     legend_title='legend_title', plot_title='plot_title'):
    figure(figsize=(10, 10), dpi=250)
    keys = list(corpus.keys())
    for i, key in enumerate(keys):
        z_model = model.transform(corpus[key])
        plt.scatter(z_model[:,0], z_model[:,1], label=key, s=point_size, c=colors[i], linewidth=0.5, edgecolor='k')
        if mass_center:
            x = np.mean(z_model[:,0])
            y = np.mean(z_model[:,1])
            plt.scatter(x, y, label=key, s=point_size, c=colors[i], marker="X")
    plt.legend(title=legend_title)
    plt.title(plot_title)
    plt.xticks([])
    plt.yticks([])

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

# %%
build_model_plot(corpus_sent_book_vecs, pca, colors=['green', 'aqua', 'red', 'black'])

# %%
import umap

mapper = umap.UMAP()

# %%
build_model_plot(corpus_sent_book_vecs, mapper)

# %%
import gensim

# %%
from razdel import sentenize, tokenize
from navec import Navec
from slovnet import Morph
import pymorphy2
#Загрузим модель для определения частей речи
navec = Navec.load('D:\\DDPronin\\PyCharm\\Fintech Hub (ВТБ)\\HW2\\model\\navec_hudlit_v1_12B_500K_300d_100q.tar')
morph = Morph.load('D:\\DDPronin\\PyCharm\\Fintech Hub (ВТБ)\\HW2\\model\\slovnet_morph_news_v1.tar', batch_size=4)
norm = pymorphy2.MorphAnalyzer()
morph.navec(navec);

# %%
# {key: [el1, el2...], ...} -> {key: [vec1, vec2...], ...}
def vectorize_w2v(corpus, vectorizer):
    keys = list(corpus.keys())
    books = list(itertools.chain.from_iterable(corpus.values())) # {key: [el1, el2...], ...} -> [el1, el2, el3, el4...]
    #Векторизация
    out = {}
    for key in keys:
        out[key] = []
        for element in corpus[key]:
            for word in element:
                
        out[key].append(vectorizer[element.split()])
    return out
# Out:
# dict_values([[array([0.        , 0.01023394, 0.        , ..., 0.        , 0.        ,
#        0.        ]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.])], [array([0.        , 0.00089685, 0.        , ..., 0.        , 0.        ,
#        0.        ]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0.        , 0.        , 0.        , ..., 0.        , 0.00360381,
# ...

# %%
data = [sentence.split() for sentence in train['text'].tolist()]
