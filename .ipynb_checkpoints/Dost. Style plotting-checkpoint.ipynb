# %%
import pandas as pd
import numpy as np
import codecs
from matplotlib import pyplot as plt

import os
import tqdm

# %%
DATA_PATH = 'D:\\DDPronin\\PyCharm\\RU Classic Literature graphs\\data\\corpus_ru'
DATA = os.listdir(DATA_PATH)
DATA
# Out:
# ['Авдеев.Варенька.1852.txt',
#  'Авдеев.Иванов.1852.txt',
#  'Авдеев.Тетрадь_из_записок_Тамарина.1852.txt',
#  'Авенариус.Поветрие.1867.txt',
#  'Авенариус.Современная_идиллия.1867.txt',
#  'Аксаков.Детские_годы_Багрова-внука.1858.txt',
#  'Аксаков.Семейная_хроника.1856.txt',
#  'Акунин.Азазель.1998.txt',
#  'Акунин.Алмазная_колесница.2003.txt',
#  'Акунин.Весь_мир_театр.2010.txt',
#  'Акунин.Декоратор.1999.txt',
#  'Акунин.Детская_книга_для_девочек.2012.txt',
#  'Акунин.Детская_книга_для_мальчиков.2005.txt',
#  'Акунин.Квест.2006.txt',
#  'Акунин.Коронация.2000.txt',
#  'Акунин.Левиафан.1998.txt',
#  'Акунин.Любовница_смерти.2001.txt',
#  'Акунин.Не_прощаюсь.2018.txt',
#  'Акунин.Нефритовые_четки.2006.txt',
#  'Акунин.Пелагия_и_белый_бульдог.2001.txt',
#  'Акунин.Пелагия_и_красный_петух.2003.txt',
#  'Акунин.Пелагия_и_черный_монах.2001.txt',
#  'Акунин.Пиковый_валет.1999.txt',
#  'Акунин.Планета_вода.2015.txt',
#  'Акунин.Просто_Маса.2021.txt',
#  'Акунин.Смерть_Ахиллеса.1998.txt',
#  'Акунин.Статский_советник.1999.txt',
#  'Акунин.Сулажин.2016.txt',
#  'Акунин.Турецкий_гамбит.1998.txt',
#  'Акунин.Фантастика.2005.txt',
#  'Акунин.Черный_город.2012.txt',
#  'Акунин.Шпионский_роман.2005.txt',
#  'Алексеев.Игра_судьбы.1913.txt',
#  'Алексеев.Лжецаревич.1898.txt',
#  'Амфитеатров.Отравленная_совесть.1890.txt',
#  'Анненская.Анна.1881.txt',
#  'Анненская.Брат_и_сестра.1908.txt',
#  'Анненская.Волчонок.1889.txt',
#  'Анненская.Младший_брат.1889.txt',
#  'Анненская.Неудачник.1889.txt',
#  'Анненская.Трудная_борьба.1889.txt',
#  'Анненская.Тяжелая_жизнь.1877.txt',
#  'Анненская.Чужой_хлеб.1872.txt',
#  'Апраксин.Ловкачи.1897.txt',
#  'Апухтин.Архив_графини_Д.1895.txt',
#  'Апухтин.Дневник_Павлика_Дольского.1895.txt',
#  'Апухтин.Неоконченная_повесть.1898.txt',
#  'Аскоченский.Асмодей_нашего_времени.1858.txt',
#  'Ахшарумов.Концы_в_воду.1872.txt',
#  'Бегичев.Семейство_Холмских.1832.txt',
#  'Бем.Княжна_Тата.1879.txt',
#  'Бестужев.Аммалат-бек.1832.txt',
#  'Бестужев.Вечер_на_Кавказских_водах_в_1824_году.1832.txt',
#  'Бестужев.Испытание.1832.txt',
#  'Бестужев.Лейтенант_Белозор.1831.txt',
#  'Бестужев.Мулла-нур.1832.txt',
#  'Бестужев.Русский_в_Париже_1814_года.1832.txt',
#  'Бестужев.Фрегат_Надежда.1832.txt',
#  'Боборыкин.Василий_Теркин.1895.txt',
#  'Боборыкин.Долго_ли.1876.txt',
#  'Боборыкин.Жертва_вечерняя.1868.txt',
#  'Боборыкин.Китай-город.1883.txt',
#  'Боборыкин.Поумнел.1897.txt',
#  'Боборыкин.Проездом.1897.txt',
#  'Богораз.Кривоногий.1896.txt',
#  'Богораз.На_реке_Росомашьей.1898.txt',
#  'Булгаков.Белая_гвардия.1923.txt',
#  'Булгаков.Дьяволиада.1923.txt',
#  'Булгаков.Записки_юного_врача.1925.txt',
#  'Булгаков.Мастер_и_Маргарита.1928.txt',
#  'Булгаков.Роковые_яйца.1924.txt',
#  'Булгаков.Театральный_роман.1936.txt',
#  'Булгарин.Димитрий_Самозванец.1830.txt',
#  'Булгарин.Иван_Иванович_Выжигин.1829.txt',
#  'Булгарин.Мазепа.1833.txt',
#  'Бутков.Невский_проспект.1848.txt',
#  'Вельтма.Им_привидeлся_сон.1846.txt',
#  'Вельтман.Кощей_бессмертный.1833.txt',
#  'Вельтман.Приключения_почерпнутые_из_моря_житейского.1848.txt',
#  'Вельтман.Райна_королевна_Болгарская.1843.txt',
#  'Вельтман.Светославич_вражий_питомец.1835.txt',
#  'Вельтман.Странник.1831.txt',
#  'Вересаев.Без_дороги.1898.txt',
#  'Вересаев.Поветрие.1898.txt',
#  'Верещагин.Литератор.1894.txt',
#  'Веселитская.Мимочка.1892.txt',
#  'Водолазкин.Авиатор.2015.txt',
#  'Водолазкин.Брисбен.2018.txt',
#  'Водолазкин.Лавр.2012.txt',
#  'Водолазкин.Оправдание_острова.2020.txt',
#  'Водолазкин.Похищение_Европы.2005.txt',
#  'Водолазкин.Соловьев_и_Ларионов.2019.txt',
#  'Водолазкин.Чагин.2023.txt',
#  'Волконский.Брат_герцога.1900.txt',
#  'Волконский.Кольцо_императрицы.1902.txt',
#  'Вонлярлярский.Большая_барыня.1852.txt',
#  'Вонлярлярский.Ночь_на_28-е_сентября.1853.txt',
#  'Высоцкой.Лето_на_хуторе.1855.txt',
#  'Ган.Идеал.1837.txt',
#  'Ган.Суд_света.1843.txt',
#  'Гарин-Михайловский.В_сутолоке_провинциальной_жизни.1896.txt',
#  'Гарин-Михайловский.Гимназисты.1895.txt',
#  'Гарин-Михайловский.Детство_Тёмы.1893.txt',
#  'Гарин-Михайловский.Студенты.1898.txt',
#  'Гаршин.Надежда_Николаевна.1888.txt',
#  'Гейнце.Аракчеев.1893.txt',
#  'Гейнце.В_тине_адвокатуры.1889.txt',
#  'Гейнце.Князь_Тавриды.1895.txt',
#  'Гейнце.Коронованный_рыцарь.1895.txt',
#  'Гейнце.Людоедка.1897.txt',
#  'Гейнце.Новгородская_вольница.1895.txt',
#  'Гейнце.Самозванец.1898.txt',
#  'Гейнце.Судные_дни_Великого_Новгорода.1897.txt',
#  'Гейнце.Сцена_и_жизнь.1895.txt',
#  'Гейнце.Тайна_высокого_дома.1894.txt',
#  'Герцен.Долг_прежде_всего.1854.txt',
#  'Герцен.Кто_виноват.1846.txt',
#  'Гиппиус.Златоцвет.1896.txt',
#  'Глинка.Заднепровские_сцены.1854.txt',
#  'Глуховский.Будущее.2013.txt',
#  'Глуховский.Дневник_ученого.2009.txt',
#  'Глуховский.Конец_дороги.2006.txt',
#  'Глуховский.Метро_2033.2007.txt',
#  'Глуховский.Метро_2034.2009.txt',
#  'Глуховский.Метро_2035.2015.txt',
#  'Глуховский.Пост_1.2019.txt',
#  'Глуховский.Пост_2.2021.txt',
#  'Глуховский.Рассказы_о_Родине.2015.txt',
#  'Глуховский.Сумерки.2007.txt',
#  'Глуховский.Текст.2017.txt',
#  'Гоголь.Вий.1835.txt',
#  'Гоголь.Мертвые_души.1842.txt',
#  'Гоголь.Повесть_о_том_как_поссорился_Иван_Иванович.1835.txt',
#  'Гоголь.Портрет.1842.txt',
#  'Гоголь.Старосветские_помещики.1835.txt',
#  'Гоголь.Тарас_Бульба.1842.txt',
#  'Гончаров.Обломов.1859.txt',
#  'Гончаров.Обрыв.1870.txt',
#  'Гончаров.Обыкновенная_история.1847.txt',
#  'Горький.Коновалов.1897.txt',
#  'Горький.Фома_Гордеев.1900.txt',
#  'Гребенка.Чайковский.1847.txt',
#  'Греч.Черная_женщина.1834.txt',
#  'Григорович.Антон_Горемыка.1872.txt',
#  'Григорович.Два_генерала.1864.txt',
#  'Григорович.Деревня.1858.txt',
#  'Григорович.Кошка_и_мышка.1858.txt',
#  'Григорович.Неудавшаяся_жизнь.1850.txt',
#  'Григорович.Пахотник_и_бархатник.1872.txt',
#  'Григорович.Переселенцы.1857.txt',
#  'Григорович.Рыбаки.1853.txt',
#  'Григорович.Свистулькин.1858.txt',
#  'Даль.Бедовик.1839.txt',
#  'Даль.Вакх_Сидоров_Чайкин.1861.txt',
#  'Даль.Павел_Алексеевич_Игривый.1861.txt',
#  'Даль.Похождения_Христиана_Христиановича_Виольдамура.1844.txt',
#  'Данилевский.Беглые_в_Новороссии.1868.txt',
#  'Данилевский.Воля_(Беглые_воротились).1864.txt',
#  'Данилевский.Княжна_Тараканова.1885.txt',
#  'Данилевский.Мирович.1877.txt',
#  'Данилевский.Потемкин_на_Дунае_1790-й_год.1877.txt',
#  'Данилевский.Сожженная_Москва.1886.txt',
#  'Дмитриев.Два_императора.1896.txt',
#  'Достоевский.Бедные_люди.1847.txt',
#  'Достоевский.Белые_ночи.1860.txt',
#  'Достоевский.Бесы.1873.txt',
#  'Достоевский.Братья_Карамазовы.1881.txt',
#  'Достоевский.Вечный_муж.1871.txt',
#  'Достоевский.Двойник.1846.txt',
#  'Достоевский.Дядюшкин_сон.1860.txt',
#  'Достоевский.Записки_из_подполья.1865.txt',
#  'Достоевский.Игрок_(Из_записок_молодого_человека).1866.txt',
#  'Достоевский.Идиот.1874.txt',
#  'Достоевский.Неточка_Незванова.1860.txt',
#  'Достоевский.Подросток.1876.txt',
#  'Достоевский.Преступление_и_наказание.1867.txt',
#  'Достоевский.Село_Степанчиково_и_его_обитатели.1860.txt',
#  'Достоевский.Униженные_и_оскорбленные.1861.txt',
#  'Достоевский.Хозяйка.1865.txt',
#  'Дриянский.Записки_мелкотравчатого.1859.txt',
#  'Дружинин.Обрученные.1857.txt',
#  'Дружинин.Полинька_Сакс.1847.txt',
#  'Дружинин.Рассказ_Алексея_Дмитрича.1865.txt',
#  'Дурова.Гудишки.1839.txt',
#  'Дурова.Игра_судьбы_или_Противозаконная_любовь.1837.txt',
#  'Дурова.Павильон.1839.txt',
#  'Дурова.Угол.1840.txt',
#  'Елпатьевский.Очерки_Сибири.1897.txt',
#  'Ермолова.В_свете_и_дома.1856.txt',
#  'Жадовская.В_стороне_от_большого_света.1857.txt',
#  'Жадовская.Отсталая.1861.txt',
#  'Желиховска.Над_пучиной.1899.txt',
#  'Желиховска.Подруги.1902.txt',
#  'Жуков.Дача_на_Петергофской_дороге.1845.txt',
#  'Загоскин.Аскольдова_могила.1833.txt',
#  'Загоскин.Брынский_лес.1846.txt',
#  'Загоскин.Искуситель.1838.txt',
#  'Загоскин.Москва_и_москвичи.1842.txt',
#  'Загоскин.Рославлев_или_Русские_в_1812_году.1831.txt',
#  'Загоскин.Русские_в_начале_осьмнадцатого_столетия.1889.txt',
#  'Загоскин.Юрий_Милославский_или_Русские_в_1612_году.1829.txt',
#  'Засодимский.Темные_силы.1876.txt',
#  'Златовратский.Золотые_сердца.1879.txt',
#  'Златовратский.Крестьяне-присяжные.1875.txt',
#  'Зотов.Два_брата_или_Москва_в_1812_году.1850.txt',
#  'Зотов.Таинственный_монах.1834.txt',
#  'Иогель.Между_вечностью_и_минутой.1881.txt',
#  'Калашников.Камчадалка.1842.txt',
#  'Карамзин.Бедная_Лиза.1792.txt',
#  'Карамзин.Наталья_боярская_дочь.1792.txt',
#  'Карамзин.Покорение_Новгорода.1802.txt',
#  'Карнович.Любовь_и_корона.1879.txt',
#  'Карнович.На_высоте_и_на_доле_Царевна_Софья_Алексеевна.1897.txt',
#  'Карнович.Придворное_кружево.1885.txt',
#  'Коган.В_глухом_местечке.1894.txt',
#  'Кокорев.Саввушка.1852.txt',
#  'Кокорев.Сибирка.1847.txt',
#  'Колбасин.Академический_переулок.1858.txt',
#  'Колбасин.Граф_Обоянский_или_Смоленск_в_1812_году.1834.txt',
#  'Корнилович.Андрей_Безыменный.1832.txt',
#  'Короленко.Без_языка.1902.txt',
#  'Короленко.В_дурном_обществе.1894.txt',
#  'Короленко.Марусина_заимка.1888.txt',
#  'Короленко.Слепой_музыкант.1888.txt',
#  'Короленко.Судный_день_(Иом-кипур).1888.txt',
#  'Кохановская.Гайка.1860.txt',
#  'Кохановская.Из_провинциальной_галереи_портретов.1863.txt',
#  'Кохановская.Любила.1858.txt',
#  'Красницкий.Гроза_Византии.1898.txt',
#  'Красницкий.Князь_Святослав.1894.txt',
#  'Красницкий.Красное_Солнышко.1902.txt',
#  'Краснов.Не_судьба.1881.txt',
#  'Крестовска.Вопль.1903.txt',
#  'Крестовска.Ранние_грозы.1889.txt',
#  'Крюков.На_тихом_Дону.1898.txt',
#  'Кугушев.Корнет_Отлетаев.1856.txt',
#  'Кульчицкий.Необыкновенный_поединок.1845.txt',
#  'Куприн.Впотьмах.1912.txt',
#  'Куприн.Молох.1903.txt',
#  'Куприн.На_переломе.1908.txt',
#  'Куприн.Олеся.1905.txt',
#  'Кущевский.Николай_Негорев_или_Благополучный_россиянин.1872.txt',
#  'Лагутенко.Владивосток_3000.2011.txt',
#  'Лажечников.Басурман.1838.txt',
#  'Лажечников.Беленькие,_черненькие,_и_серенькие.1858.txt',
#  'Лажечников.Внучка_панцирного_боярина.1868.txt',
#  'Лажечников.Ледяной_дом.1835.txt',
#  'Лажечников.Последний_Новик_или_Завоевание_Лифляндии.1833.txt',
#  'Лебедев.За_святую_обитель.1900.txt',
#  'Левитов.Накануне_Христова_дня.1861.txt',
#  'Лейкин.Актеры-любители.1891.txt',
#  'Лейкин.В_гостях_у_турок.1897.txt',
#  'Лейкин.Где_апельсины_зреют.1893.txt',
#  'Лейкин.Два_соперника.1891.txt',
#  'Лейкин.На_заработках.1892.txt',
#  'Лейкин.Наши_заграницей.1892.txt',
#  'Леонтьев.Аспазия_Ламприди.1876.txt',
#  'Леонтьев.В_своем_краю.1864.txt',
#  'Леонтьев.Дитя_души.1876.txt',
#  'Леонтьев.Египетский_голубь.1881.txt',
#  'Леонтьев.Исповедь_мужа_(Ай-Бурун).1867.txt',
#  'Леонтьев.Корделия.1891.txt',
#  'Леонтьев.Пембе.1870.txt',
#  'Леонтьев.Сфакиот.1877.txt',
#  'Леонтьев.Хризо.1876.txt',
#  'Лермонтов.Вадим.1873.txt',
#  'Лермонтов.Герой_нашего_времени.1840.txt',
#  'Лермонтов.Княгиня_Лиговская.1891.txt',
#  'Лесков.Аскалонский_злодей.1889.txt',
#  'Лесков.Воительница.1873.txt',
#  'Лесков.Детские_годы.1876.txt',
#  'Лесков.Железная_воля.1876.txt',
#  'Лесков.Житие_одной_бабы.1863.txt',
#  'Лесков.Загадочный_человек.1871.txt',
#  'Лесков.Запечатленный_ангел.1874.txt',
#  'Лесков.Захудалый_род.1875.txt',
#  'Лесков.Заячий_ремиз.1922.txt',
#  'Лесков.Интересные_мужчины.1886.txt',
#  'Лесков.Колыванский_муж.1888.txt',
#  'Лесков.Леди_Макбет_Мценского_уезда.1889.txt',
#  'Лесков.На_краю_света.1876.txt',
#  'Лесков.На_ножах.1871.txt',
#  'Лесков.Некуда.1865.txt',
#  'Лесков.Обойденные.1866.txt',
#  'Лесков.Оскорбленная_Нетэта.1917.txt',
#  'Лесков.Островитяне.1866.txt',
#  'Лесков.Очарованный_странник.1874.txt',
#  'Лесков.Павлин.1876.txt',
#  'Лесков.Печерские_антики.1883.txt',
#  'Лесков.Полунощники.1893.txt',
#  'Лесков.Смех_и_горе.1871.txt',
#  'Лесков.Соборяне.1872.txt',
#  'Лесков.Старые_годы_в_селе_Плодомасове.1888.txt',
#  'Лесков.Чёртовы_куклы.1890.txt',
#  'Линев.Пo_тюрьмам.1878.txt',
#  'Лухманов.Девочки.1896.txt',
#  'Маклаков.Девочка_Лида.1875.txt',
#  'Максимов.Сибирь_и_каторга.1862.txt',
#  'Мамин-Сибиряк.Бойцы.1889.txt',
#  'Мамин-Сибиряк.Братья_Гордеевы.1896.txt',
#  'Мамин-Сибиряк.В_горах.1898.txt',
#  'Мамин-Сибиряк.Верный_раб.1901.txt',
#  'Мамин-Сибиряк.Весенние_грозы.1895.txt',
#  'Мамин-Сибиряк.Горное_гнездо.1890.txt',
#  'Мамин-Сибиряк.Золото.1895.txt',
#  'Мамин-Сибиряк.Золотуха.1889.txt',
#  'Мамин-Сибиряк.Именинник.1888.txt',
#  'Мамин-Сибиряк.На_рубеже_Азии.1882.txt',
#  'Мамин-Сибиряк.Охонины_брови.1896.txt',
#  'Мамин-Сибиряк.Приваловские_миллионы.1897.txt',
#  'Мамин-Сибиряк.Сестры.1883.txt',
#  'Мамин-Сибиряк.Три_конца.1895.txt',
#  'Мамин-Сибиряк.Хлеб.1896.txt',
#  'Мамин-Сибиряк.Черты_из_жизни_Пепко.1895.txt',
#  'Маркевич.Бездна.1883.txt',
#  'Маркевич.Две_маски.1874.txt',
#  'Маркевич.Забытый_вопрос.1872.txt',
#  'Маркевич.Лесник.1880.txt',
#  'Маркевич.Марина_из_Алого_Рога.1873.txt',
#  'Маркевич.Типы_прошлого.1868.txt',
#  'Масальский.Осада_Углича.1841.txt',
#  'Масальский.Регентство_Бирона.1834.txt',
#  'Масальский.Стрельцы.1832.txt',
#  'Масальский.Черный_ящик.1833.txt',
#  'Мачтет.В_тундре_и_в_тайге.1893.txt',
#  'Мельников-Печерский.В_лесах.1826.txt',
#  'Мельников-Печерский.На_горах.1826.txt',
#  'Мельников-Печерский.Старые_годы.1876.txt',
#  'Меньшиков.Диета_души.1861.txt',
#  'Мердер.Авантюристы.1915.txt',
#  'Мердер.В_поисках_истины.1895.txt',
#  'Мердер.Воротынцевы.1891.txt',
#  'Мердер.Звезда_цесаревны.1906.txt',
#  'Мердер.Перед_разгромом.1904.txt',
#  'Мердер.Последний_из_Воротынцевых.1896.txt',
#  'Мердер.Тайный_брак.1910.txt',
#  'Мердер.Царский_приказ.1915.txt',
#  'Михайлов.Адам_Адамыч.1859.txt',
#  'Мордовцев.Великий_раскол.1881.txt',
#  'Мордовцев.Господин_Великий_Новгород.1882.txt',
#  'Мордовцев.Двенадцатый_год.1901.txt',
#  'Мордовцев.Державный_плотник.1899.txt',
#  'Мордовцев.За_чьи_грехи.1891.txt',
#  'Мордовцев.Замурованная_царица.1891.txt',
#  'Мордовцев.Ирод.1897.txt',
#  'Мордовцев.Мамаево_побоище.1881.txt',
#  'Мордовцев.Наносная_беда.1899.txt',
#  'Мордовцев.Сидение_раскольников_в_соловках.1880.txt',
#  'Мордовцев.Социалист_прошлого_века.1885.txt',
#  'Мордовцев.Тень_Ирода.1878.txt',
#  'Мордовцев.Фанатик.1891.txt',
#  'Москвин.Невольная_преступница.1913.txt',
#  'Набоков.Ада.1969.txt',
#  'Набоков.Дар.1938.txt',
#  'Набоков.Защита_Лужина.1930.txt',
#  'Набоков.Казнь.1936.txt',
#  'Набоков.Камера.1933.txt',
#  'Набоков.Король.1928.txt',
#  'Набоков.Лолита.1955.txt',
#  'Набоков.Машенька.1926.txt',
#  'Набоков.Отчаяние.1934.txt',
#  'Набоков.Пнин_пер_Барлабтарло.1957.txt',
#  'Набоков.Пнин_пер_Ильин.1957.txt',
#  'Набоков.Пнин_пер_Носик.1957.txt',
#  'Набоков.Под_знаком_незаконорожденных_пер_Ильин.1947.txt',
#  'Набоков.Подвиг.1932.txt',
#  'Набоков.Прозрачные_вещи_пер_Ильин.1972.txt',
#  'Набоков.Себастьян_Найт.1941.txt',
#  'Набоков.Смотри_на_арлекинов.1974.txt',
#  'Нарежный.Бурсак.1824.txt',
#  'Нарежный.Два_Ивана_или_Страсть_к_тяжбам.1825.txt',
#  'Нарежный.Запорожец.1836.txt',
#  'Нарежный.Российский_Жилблаз.1814.txt',
#  'Наумов.Святое_озеро.1882.txt',
#  'Наумов.Юровая.1874.txt',
#  'Некрасов.Мертвое_озеро.1852.txt',
#  'Некрасов.Три_страны_света.1849.txt',
#  'Немирович-Данченко.С_дипломом.1894.txt',
#  'Никитин.Многострадальные.1871.txt',
#  'Одоевский.Саламандра.1841.txt',
#  'Омулевский.Попытка_-_не_шутка.1873.txt',
#  'Омулевский.Шаг_за_шагом.1871.txt',
#  'Павлов.Маскарад.1839.txt',
#  'Павлов.Три_повести.1835.txt',
#  'Панаев.Актеон.1857.txt',
#  'Панаев.Белая_горячка.1840.txt',
#  'Панаев.Дочь_чиновного_человека.1839.txt',
#  'Панаев.Она_будет_счастлива.1836.txt',
#  'Панаев.Онагр.1857.txt',
#  'Панаев.Прекрасный_человек.1857.txt',
#  'Панаев.Родственники.1860.txt',
#  'Панаев.Сегодня_и_завтра.1837.txt',
#  'Панаев.Семейство_Тальниковых.1848.txt',
#  'Панаев.Спальня_светской_женщины.1835.txt',
#  'Панаев.Степная_барышня.1855.txt',
#  'Пелевин.Generation_П.1999.txt',
#  'Пелевин.iPhuck10.2017.txt',
#  'Пелевин.KGBT_plus.2022.txt',
#  'Пелевин.SNUFF.2011.txt',
#  'Пелевин.t.2009.txt',
#  'Пелевин.Transhumanism_Inc.2021.txt',
#  'Пелевин.Ампир_В.2006.txt',
#  'Пелевин.Бэтман_Аполло.2013.txt',
#  'Пелевин.Железная_бездна.2015.txt',
#  'Пелевин.Жизнь_насекомых.1993.txt',
#  'Пелевин.Лампа_Мафусаила.2016.txt',
#  'Пелевин.Любовь_к_трем_цукербринам.2014.txt',
#  'Пелевин.Непобедимое_Солнце.2020.txt',
#  'Пелевин.Орден_желтого_флага.2015.txt',
#  'Пелевин.Священная_книга_оборотня.2004.txt',
#  'Пелевин.Тайные_виды_на_гору_Фудзи.2018.txt',
#  'Пелевин.Чапаев_и_Пустота.1996.txt',
#  'Пелевин.Числа.2003.txt',
#  'Писемский.Боярщина.1861.txt',
#  'Писемский.В_водовороте.1872.txt',
#  'Писемский.Взбаламученное_море.1863.txt',
#  'Писемский.Виновата_ли_она.1861.txt',
#  'Писемский.Комик.1861.txt',
#  'Писемский.Люди_сороковых_годов.1869.txt',
#  'Писемский.Масоны.1880.txt',
#  'Писемский.Мещане.1878.txt',
#  'Писемский.Сергей_Петрович_Хозаров_и_Мари_Ступицына.1851.txt',
#  'Писемский.Старческий_грех.1861.txt',
#  'Писемский.Тысяча_душ.1858.txt',
#  'Писемский.Тюфяк.1850.txt',
#  'Писемский.Фанфарон.1859.txt',
#  'Плещеев.Дружеские_советы.1849.txt',
#  'Плещеев.Отец_и_дочь.1860.txt',
#  'Плещеев.Пашинцев.1880.txt',
#  'Погодин.Невеста_на_ярмарке.1837.txt',
#  'Погорельский.Двойник.1828.txt',
#  'Погорельский.Монастырка.1833.txt',
#  'Позняков.Товарищ.1896.txt',
#  'Полевой.Блаженство_безумия.1833.txt',
#  'Полевой.Живописец.1834.txt',
#  'Полевой.Избранник_Божий.1899.txt',
#  'Полевой.Иоанн_Цимисхий.1841.txt',
#  'Полевой.Клятва_при_гробе_Господнем.1832.txt',
#  'Полевой.Повесть_о_Симеоне_суздальском_князе.1843.txt',
#  'Полевой.Рассказы_русского_солдата.1834.txt',
#  'Полевой.Эмма.1834.txt',
#  'Помяловский.Мещанское_счастье.1861.txt',
#  'Помяловский.Молотов.1861.txt',
#  'Помяловский.Очерки_бурсы.1865.txt',
#  'Потапенко.Не_герой.1896.txt',
#  'Потапенко.Секретарь_его_превосходительства.1891.txt',
#  'Потапенко.Шестеро.1894.txt',
#  'Пушкин.Дубровский.1841.txt',
#  'Пушкин.Капитанская_дочка.1836.txt',
#  'Пушкин.Пиковая_дама.1834.txt',
#  'Пушкин.Повести_Белкина.1831.txt',
#  'Радищев.Путешествие_из_Петербурга_в_Москву.1790.txt',
#  'Ремезов.Ничьи_деньги.1880.txt',
#  'Решетников.Где_лучше.1869.txt',
#  'Решетников.Горнорабочие.1861.txt',
#  'Решетников.Между_людьми.1869.txt',
#  'Решетников.Подлиповцы.1867.txt',
#  'Решетников.Ставленник.1869.txt',
#  'Ростопчин.Палаццо_Форли.1854.txt',
#  'Ростопчин.Поединок.1838.txt',
#  'Ростопчин.Счастливая_женщина.1851.txt',
#  'Салиас-де-Турнемир.Аракчеевский_подкидыш.1889.txt',
#  'Салиас-де-Турнемир.Аракчеевский_сынок.1888.txt',
#  'Салиас-де-Турнемир.Крутоярская_царевна.1893.txt',
#  'Салиас-де-Турнемир.Кудесник.1887.txt',
#  'Салиас-де-Турнемир.На_Москве_(Мор).1885.txt',
#  'Салиас-де-Турнемир.Петербургское_действо.1880.txt',
#  'Салиас-де-Турнемир.Семейство_Шалонских.1880.txt',
#  'Салиас-де-Турнемир.Старушка.1859.txt',
#  'Салиас-де-Турнемир.Филозоф.1891.txt',
#  'Салиас-де-Турнемир.Фрейлина_императрицы.1887.txt',
#  'Салиас-де-Турнемир.Ширь_и_мах_(Миллион).1892.txt',
#  'Салов.Грачевский_крокодил.1879.txt',
#  'Салов.Николай_Суетной.1894.txt',
#  'Салтыков-Щедрин.Благонамеренные_речи.1876.txt',
#  'Салтыков-Щедрин.В_больнице_для_умалишенных.1873.txt',
#  'Салтыков-Щедрин.Господа_Головлевы.1880.txt',
#  'Салтыков-Щедрин.Дневник_провинциала_в_Петербурге.1873.txt',
#  'Салтыков-Щедрин.История_одного_города.1870.txt',
#  'Салтыков-Щедрин.Помпадуры_и_помпадурши.1873.txt',
#  'Салтыков-Щедрин.Пошехонская_старина.1887.txt',
#  'Салтыков-Щедрин.Современная_идиллия.1883.txt',
#  'Салтыков-Щедрин.Убежище_Монрепо.1880.txt',
#  'Семёнов.Два_сфинкса.1900.txt',
#  'Семёнов.Заколдованный_замок.1898.txt',
#  'Семёнов.Месть_еврея.1892.txt',
#  'Семёнов.Рекенштейны.1894.txt',
#  'Семёнов.Царица_Хатасу.1894.txt',
#  'Сенковский.Вся_женская_жизнь_в_нескольких_часах.1856.txt',
#  'Сенковский.Ученое_путешествие_на_Медвежий_Остров.1858.txt',
#  'Славутинский.Жизнь_и_похождения_Трифона_Афанасьева.1860.txt',
#  'Славутинский.Мирская_беда.1860.txt',
#  'Славутинский.Читальщица.1860.txt',
#  'Слепцов.Трудное_время.1866.txt',
#  'Соколовский.Одна_и_две.1834.txt',
#  'Соллогуб.Большой_свет.1840.txt',
#  'Соллогуб.Старушка.1850.txt',
#  'Соллогуб.Тарантас.1845.txt',
#  'Соловьев.Великий_розенкрейцер.1890.txt',
#  'Соловьев.Волхвы.1879.txt',
#  'Соловьев.Вольтерьянец.1883.txt',
#  'Соловьев.Изгнанник.1884.txt',
#  'Соловьев.Капитан_гренадерской_роты.1878.txt',
#  'Соловьев.Княжна_Острожская.1877.txt',
#  'Соловьев.Последние_Горбатовы.1887.txt',
#  'Соловьев.Сергей_Горбатов.1883.txt',
#  'Соловьев.Старый_дом.1884.txt',
#  'Соловьев.Царское_посольство.1893.txt',
#  'Соловьев.Царь-девица.1878.txt',
#  'Соловьев.Юный_император.1879.txt',
#  'Сомов.Гайдамак.1826.txt',
#  'Сорокин.De_femimis.2022.txt',
#  'Сорокин.Голубое_сало.1999.txt',
#  'Сорокин.День_опричника.2006.txt',
#  'Сорокин.Ледяная_трилогия.2004.txt',
#  'Сорокин.Тридцатая_любовь_Марины.1983.txt',
#  'Станюкович.В_мутной_воде.1873.txt',
#  'Станюкович.Василий_Иванович.1895.txt',
#  'Станюкович.Вокруг_света_на_Коршуне.1896.txt',
#  'Станюкович.Грозный_адмирал.1896.txt',
#  'Станюкович.Два_брата.1881.txt',
#  'Станюкович.Женитьба_Пинегина.1897.txt',
#  'Станюкович.Жрецы.1906.txt',
#  'Станюкович.История_одной_жизни.1896.txt',
#  'Станюкович.Мрачный_штурман.1893.txt',
#  'Станюкович.Нянька.1901.txt',
#  'Станюкович.Пассажирка.1893.txt',
#  'Станюкович.Похождения_одного_благонамеренного.1879.txt',
#  'Станюкович.Похождения_одного_матроса.1913.txt',
#  'Станюкович.Равнодушные.1906.txt',
#  'Старостин.Наше_счастие.1901.txt',
#  'Старостин.Последняя.1901.txt',
#  'Старостин.Похождения_семинариста_Хлопова.1901.txt',
#  'Сухонин.На_рубеже_столетий.1884.txt',
#  'Телешов.На_тройках.1895.txt',
#  'Терпигорев.Марфинькино_счастье.1888.txt',
#  'Тимофеев.Художник.1834.txt',
#  'Толстой.Анна_Каренина.1878.txt',
#  'Толстой.Война_и_мир.1868.txt',
#  'Толстой.Воскресение.1899.txt',
#  'Толстой.Два_Гусара.1864.txt',
#  'Толстой.Детство.1856.txt',
#  'Толстой.Казаки.1864.txt',
#  'Толстой.Князь_Серебряный.1863.txt',
#  'Толстой.Крейцерова_соната.1890.txt',
#  'Толстой.Отрочество.1856.txt',
#  'Толстой.Поликушка.1864.txt',
#  'Толстой.Севастополь_в_августе_1855_года.1856.txt',
#  'Толстой.Семейное_счастье.1873.txt',
#  'Толстой.Смерть_Ивана_Ильича.1886.txt',
#  'Толстой.Упырь.1841.txt',
#  'Толстой.Юность.1864.txt',
#  'Тургенев.Вешние_воды.1873.txt',
#  'Тургенев.Два_приятеля.1860.txt',
#  'Тургенев.Дворянское_гнездо.1859.txt',
#  'Тургенев.Дневник_лишнего_человека.1850.txt',
#  'Тургенев.Дым.1867.txt',
#  'Тургенев.Затишье.1856.txt',
#  'Тургенев.Клара_Милич_(После_смерти).1883.txt',
#  'Тургенев.Накануне.1860.txt',
#  'Тургенев.Несчастная.1869.txt',
#  'Тургенев.Новь.1877.txt',
#  'Тургенев.Отцы_и_дети.1862.txt',
#  'Тургенев.Первая_любовь.1860.txt',
#  'Тургенев.Постоялый_двор.1856.txt',
#  'Тургенев.Рудин.1856.txt',
#  'Тургенев.Степной_король_Лир.1873.txt',
#  'Успенский.Нравы_растеряевой_улицы.1866.txt',
#  'Филиппов.Осажденный_Севастополь.1888.txt',
#  'Фонвизин.Недоросоль.1782.txt',
#  'Фурман.Саардамский_плотник.1847.txt',
#  'Хвощинска.Братец.1858.txt',
#  'Хвощинска.Пансионерка.1861.txt',
#  'Хвощинска.Первая_борьба.1879.txt',
#  'Хомяков.Светлое_Воскресенье.1900.txt',
#  'Чернышевский.Что_делать.1863.txt',
#  'Чехов.В_овраге.1900.txt',
#  'Чехов.Дуэль.1892.txt',
#  'Чехов.Моя_жизнь.1897.txt',
#  'Чехов.Палата_No_6.1894.txt',
#  'Чехов.Рассказ_неизвестного_человека.1901.txt',
#  'Чехов.Степь.1888.txt',
#  'Чехов.Три_года.1895.txt',
#  'Шаликова.Семейные_сцены.1856.txt',
#  'Шапи.Авдотьины_дочки.1901.txt',
#  'Шеллер-Михайлов.Господа_Обносковы.1870.txt',
#  'Шеллер-Михайлов.Дворец_и_монастырь.1890.txt',
#  'Шеллер-Михайлов.Лес_рубят_-_щепки_летят.1871.txt',
#  'Шеллер-Михайлов.Над_обрывом.1884.txt',
#  'Шкляревский.Рассказ_судебного_следователя.1879.txt',
#  'Шкляревский.Секретное_следствие.1881.txt',
#  'Шкляревский.Что_побудило_к_убийству.1879.txt',
#  'Эртель.Волхонская_барышня.1883.txt',
#  'Эртель.Гарденины,_их_дворня,_приверженцы_и_враги.1890.txt',
#  'Эртель.Две_пары.1894.txt',
#  'Эртель.Карьера_Струкова.1895.txt',
#  'Юрковский.(Заключенный_N_10).1933.txt',
#  'Якубович.В_мире_отверженных.1896.txt',
#  'Ясинский.Бунт_Ивана_Иваныча.1886.txt',
#  'Ясинский.Верочка.1887.txt',
#  'Ясинский.Учитель.1888.txt',
#  'Яхина.Дети_мои.2018.txt',
#  'Яхина.Зулейха_открывает_глаза.2015.txt',
#  'Яхина.Эшелон_до_Самарканд.2021.txt']

# %%
AUTHORS = sorted(list(set([element.replace('_','.').split('.')[0] for element in DATA])))
print('Авторов: ', len(AUTHORS))
print('Книг: ', len(DATA))
# Out:
# Авторов:  159
# Книг:  604

# %%
#Функция для считывания книг в словарь
def to_dict(DATA_PATH, BOOKS):
    out_dict = {}
    for name in BOOKS:
        with open(f'{DATA_PATH}\\{name}', encoding="utf-8") as f:
            out_dict[name[:-4]] = ' '.join(f.read().split())
    return out_dict

# %%
# %%time
corpus = {}
for author in tqdm.tqdm(AUTHORS):
    author_books = []
    for i in range(len(DATA)):
        if author == DATA[i].split('.')[0]:
            author_books.append(DATA[i])
    corpus[author] = to_dict(DATA_PATH, author_books)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 159/159 [00:10<00:00, 14.79it/s]
# Wall time: 10.8 s

# %%
def moving_average(a, n=3):
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
def moving_window(a, n=2):
    ret = []
    a = n*[0] + list(a) + n*[0]
    for i in range(n, len(a)-n):
        ret.append(sum(a[i-n:i+n])/(2*n+1))
    return ret

# %%
from razdel import sentenize
from dostoevsky.tokenization import RegexTokenizer
from dostoevsky.models import FastTextSocialNetworkModel

tokenizer = RegexTokenizer()
model = FastTextSocialNetworkModel(tokenizer=tokenizer)

def tonalnost(book, n):
    substrings = list(sentenize(book))
    sents = []
    for i in range(len(substrings)):
        sents.append(substrings[i].text)
    messages = sents
    results = model.predict(messages, k=2)
    neu, pos, neg, sp = [], [], [], []
    for message, sentiment in zip(messages, results):
        if 'neutral' not in sentiment.keys():
            sentiment['neutral'] = 0
        if 'positive' not in sentiment.keys():
            sentiment['positive'] = 0
        if 'negative' not in sentiment.keys():
            sentiment['negative'] = 0
        if 'speech' not in sentiment.keys():
            sentiment['speech'] = 0
        neu.append(sentiment['neutral'])
        pos.append(sentiment['positive'])
        neg.append(sentiment['negative'])
        sp.append(sentiment['speech'])
    plt.plot(moving_window(np.array(pos)-np.array(neg), n))
    plt.plot(moving_average(np.array(pos)-np.array(neg), n))
    #plt.plot(moving_average(neu, 20))
    #plt.plot(moving_average(pos, 20))
    #plt.plot(moving_average(neg, 20))
    #plt.plot(moving_average(sp, 20))
    #return {'neutral' : neu, 'positive' : pos, 'negative' : neg, 'speech' : sp}
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
text = corpus['Пушкин']['Пушкин.Дубровский.1841']

# %%
corpus['Пушкин']['Пушкин.Дубровский.1841'].split('.')[0:100]
# Out:
# ['Александр Сергеевич Пушкин Дубровский 1832–1833 ТОМ ПЕРВЫЙ ГЛАВА I Несколько лет тому назад в одном из своих поместий жил старинный русский барин, Кирила Петрович Троекуров',
#  ' Его богатство, знатный род и связи давали ему большой вес в губерниях, где находилось его имение',
#  ' Соседи рады были угождать малейшим его прихотям; губернские чиновники трепетали при его имени; Кирила Петрович принимал знаки подобострастия как надлежащую дань; дом его всегда был полон гостями, готовыми тешить его барскую праздность, разделяя шумные, а иногда и буйные его увеселения',
#  ' Никто не дерзал отказываться от его приглашения или в известные дни не являться с должным почтением в село Покровское',
#  ' В домашнем быту Кирила Петрович выказывал все пороки человека необразованного',
#  ' Избалованный всем, что только окружало его, он привык давать полную волю всем порывам пылкого своего нрава и всем затеям довольно ограниченного ума',
#  ' Несмотря на необыкновенную силу физических способностей, он раза два в неделю страдал от обжорства и каждый вечер бывал навеселе',
#  ' В одном из флигелей его дома жили шестнадцать горничных, занимаясь рукоделиями, свойственными их полу',
#  ' Окны во флигеле были загорожены деревянною решеткою; двери запирались замками, от коих ключи хранились у Кирила Петровича',
#  ' Молодые затворницы в положенные часы сходили в сад и прогуливались под надзором двух старух',
#  ' От времени до времени Кирила Петрович выдавал некоторых из них замуж, и новые поступали на их место',
#  ' С крестьянами и дворовыми обходился он строго и своенравно; несмотря на то, они были ему преданы: они тщеславились богатством и славою своего господина и в свою очередь позволяли себе многое в отношении к их соседям, надеясь на его сильное покровительство',
#  ' Всегдашние занятия Троекурова состояли в разъездах около пространных его владений, в продолжительных пирах и в проказах, ежедневно притом изобретаемых и жертвою коих бывал обыкновенно какой-нибудь новый знакомец; хотя и старинные приятели не всегда их избегали за исключением одного Андрея Гавриловича Дубровского',
#  ' Сей Дубровский, отставной поручик гвардии, был ему ближайшим соседом и владел семидесятью душами',
#  ' Троекуров, надменный в сношениях с людьми самого высшего звания, уважал Дубровского несмотря на его смиренное состояние',
#  ' Некогда были они товарищами по службе, и Троекуров знал по опыту нетерпеливость и решительность его характера',
#  ' Обстоятельства разлучили их надолго',
#  ' Дубровский с расстроенным состоянием принужден был выйти в отставку и поселиться в остальной своей деревне',
#  ' Кирила Петрович, узнав о том, предлагал ему свое покровительство, но Дубровский благодарил его и остался беден и независим',
#  ' Спустя несколько лет Троекуров, отставной генерал-аншеф, приехал в свое поместие, они свиделись и обрадовались друг другу',
#  ' С тех пор они каждый день бывали вместе, и Кирила Петрович, отроду не удостоивавший никого своим посещением, заезжал запросто в домишко своего старого товарища',
#  ' Будучи ровесниками, рожденные в одном сословии, воспитанные одинаково, они сходствовали отчасти и в характерах и в наклонностях',
#  ' В некоторых отношениях и судьба их была одинакова: оба женились по любви, оба скоро овдовели, у обоих оставалось по ребенку',
#  ' Сын Дубровского воспитывался в Петербурге, дочь Кирила Петровича росла в глазах родителя, и Троекуров часто говаривал Дубровскому: "Слушай, брат, Андрей Гаврилович: коли в твоем Володьке будет путь, так отдам за него Машу; даром что он гол как сокол"',
#  ' Андрей Гаврилович качал головой и отвечал обыкновенно: "Нет, Кирила Петрович: мой Володька не жених Марии Кириловне',
#  ' Бедному дворянину, каков он, лучше жениться на бедной дворяночке, да быть главою в доме, чем сделаться приказчиком избалованной бабенки"',
#  ' Все завидовали согласию, царствующему между надменным Троекуровым и бедным его соседом, и удивлялись смелости сего последнего, когда он за столом у Кирила Петровича прямо высказывал свое мнение, не заботясь о том, противуречило ли оно мнениям хозяина',
#  ' Некоторые пытались было ему подражать и выйти из пределов должного повиновения, но Кирила Петрович так их пугнул, что навсегда отбил у них охоту к таковым покушениям, и Дубровский один остался вне общего закона',
#  ' Нечаянный случай все расстроил и переменил',
#  ' Раз в начале осени Кирила Петрович собирался в отъезжее поле',
#  ' Накануне был отдан приказ псарям и стремянным быть готовыми к пяти часам утра',
#  ' Палатка и кухня отправлены были вперед на место, где Кирила Петрович должен был обедать',
#  ' Хозяин и гости пошли на псарный двор, где более пятисот гончих и борзых жили в довольстве и тепле, прославляя щедрость Кирила Петровича на своем собачьем языке',
#  ' Тут же находился и лазарет для больных собак, под присмотром штаб-лекаря Тимошки, и отделение, где благородные суки ощенялись и кормили своих щенят',
#  ' Кирила Петрович гордился сим прекрасным заведением и никогда не упускал случая похвастаться оным перед своими гостями, из коих каждый осмотривал его по крайней мере уже в двадцатый раз',
#  ' Он расхаживал по псарне, окруженный своими гостями и сопровождаемый Тимошкой и главными псарями; останавливался пред некоторыми конурами, то расспрашивая о здоровии больных, то делая замечания более или менее строгие и справедливые, то подзывая к себе знакомых собак и ласково с ними разговаривая',
#  ' Гости почитали обязанностию восхищаться псарнею Кирила Петровича',
#  ' Один Дубровский молчал и хмурился',
#  ' Он был горячий охотник',
#  ' Его состояние позволяло ему держать только двух гончих и одну свору борзых; он не мог удержаться от некоторой зависти при виде сего великолепного заведения',
#  ' "Что же ты хмуришься, брат, -- спросил его Кирила Петрович, -- или псарня моя тебе не нравится?" -- "Нет, -- отвечал он сурово, -- псарня чудная, вряд людям вашим житье такое ж, как вашим собакам"',
#  ' Один из псарей обиделся',
#  ' "Мы на свое житье, -- сказал он, -- благодаря бога и барина не жалуемся, а что правда, то правда, иному и дворянину не худо бы променять усадьбу на любую здешнюю конурку',
#  ' Ему было б и сытнее и теплее"',
#  ' Кирила Петрович громко засмеялся при дерзком замечании своего холопа, а гости вослед за ним захохотали, хотя и чувствовали, что шутка псаря могла отнестися и к ним',
#  ' Дубровский побледнел и не сказал ни слова',
#  ' В сие время поднесли в лукошке Кирилу Петровичу новорожденных щенят; он занялся ими, выбрал себе двух, прочих велел утопить',
#  ' Между тем Андрей Гаврилович скрылся, и никто того не заметил',
#  ' Возвратясь с гостями со псарного двора, Кирила Петрович сел ужинать и тогда только, не видя Дубровского, хватился о нем',
#  ' Люди отвечали, что Андрей Гаврилович уехал домой',
#  ' Троекуров велел тотчас его догнать и воротить непременно',
#  ' Отроду не выезжал он на охоту без Дубровского, опытного и тонкого ценителя псовых достоинств и безошибочного решителя всевозможных охотничьих споров',
#  ' Слуга, поскакавший за ним, воротился, как еще сидели за столом, и доложил своему господину, что, дескать, Андрей Гаврилович не послушался и не хотел воротиться',
#  ' Кирила Петрович, по обыкновению своему разгоряченный наливками, осердился и вторично послал того же слугу сказать Андрею Гавриловичу, что если он тотчас же не приедет ночевать в Покровское, то он, Троекуров, с ним навеки рассорится',
#  ' Слуга снова поскакал, Кирила Петрович встал из-за стола, отпустил гостей и отправился спать',
#  ' На другой день первый вопрос его был: здесь ли Андрей Гаврилович? Вместо ответа ему подали письмо, сложенное треугольником; Кирила Петрович приказал своему писарю читать его вслух и услышал следующее: "Государь мой премилостивый, Я до тех пор не намерен ехать в Покровское, пока не вышлете Вы мне псаря Парамошку с повинною; а будет моя воля наказать его или помиловать, а я терпеть шутки от Ваших холопьев не намерен, да и от Вас их не стерплю, потому что я не шут, а старинный дворянин',
#  ' За сим остаюсь покорным ко услугам Андрей Дубровский"',
#  ' По нынешним понятиям об этикете письмо сие было бы весьма неприличным, но оно рассердило Кирила Петровича не странным слогом и расположением, но только своею сущностью: "Как, -- загремел Троекуров, вскочив с постели босой, -- высылать к ему моих людей с повинной, он волен их миловать, наказывать! да что он в самом деле задумал; да знает ли он, с кем связывается? Вот я ж его',
#  '',
#  '',
#  ' Наплачется он у меня, узнает, каково идти на Троекурова!" Кирила Петрович оделся и выехал на охоту с обыкновенной своею пышностию, но охота не удалась',
#  ' Во весь день видели одного только зайца и того протравили',
#  ' Обед в поле под палаткою также не удался, или по крайней мере был не по вкусу Кирила Петровича, который прибил повара, разбранил гостей и на возвратном пути со всею своей охотою нарочно поехал полями Дубровского',
#  ' Прошло несколько дней, и вражда между двумя соседами не унималась',
#  ' Андрей Гаврилович не возвращался в Покровское -- Кирила Петрович без него скучал, и досада его громко изливалась в самых оскорбительных выражениях, которые, благодаря усердию тамошних дворян, доходили до Дубровского исправленные и дополненные',
#  ' Новое обстоятельство уничтожило и последнюю надежду на примирение',
#  ' Дубровский объезжал однажды малое свое владение; приближаясь к березовой роще, услышал он удары топора и через минуту треск повалившегося дерева',
#  ' Он поспешил в рощу и наехал на покровских мужиков, спокойно ворующих у него лес',
#  ' Увидя его, они бросились было бежать',
#  ' Дубровский со своим кучером поймал из них двоих и привел их связанных к себе на двор',
#  ' Три неприятельские лошади достались тут же в добычу победителю',
#  ' Дубровский был отменно сердит, прежде сего никогда люди Троекурова, известные разбойники, не осмеливались шалить в пределах его владений, зная приятельскую связь его с их господином',
#  ' Дубровский видел, что теперь пользовались они происшедшим разрывом, -- и решился, вопреки всем понятиям о праве войны, проучить своих пленников прутьями, коими запаслись они в его же роще, а лошадей отдать в работу, приписав к барскому скоту',
#  ' Слух о сем происшествии в тот же день дошел до Кирила Петровича',
#  ' Он вышел из себя и в первую минуту гнева хотел было со всеми своими дворовыми учинить нападение на Кистеневку (так называлась деревня его соседа), разорить ее дотла и осадить самого помещика в его усадьбе',
#  ' Таковые подвиги были ему не в диковину',
#  ' Но мысли его вскоре приняли другое направление',
#  ' Расхаживая тяжелыми шагами взад и вперед по зале, он взглянул нечаянно в окно и увидел у ворот остановившуюся тройку; маленький человек в кожаном картузе и фризовой шинели вышел из телеги и пошел во флигель к приказчику; Троекуров узнал заседателя Шабашкина и велел его позвать',
#  ' Через минуту Шабашкин уже стоял перед Кирилом Петровичем, отвешивая поклон за поклоном и с благоговением ожидая его приказаний',
#  ' -- Здорово, как, бишь, тебя зовут, -- сказал ему Троекуров, -- зачем пожаловал? -- Я ехал в город, ваше превосходительство, -- отвечал Шабашкин, -- и зашел к Ивану Демьянову узнать, не будет ли какого приказания от вашего превосходительства',
#  ' -- Очень кстати заехал, как, бишь, тебя зовут; мне до тебя нужда',
#  ' Выпей водки да выслушай',
#  ' Таковой ласковый прием приятно изумил заседателя',
#  ' Он отказался от водки и стал слушать Кирила Петровича со всевозможным вниманием',
#  ' -- У меня сосед есть, -- сказал Троекуров, -- мелкопоместный грубиян; я хочу взять у него имение, -- как ты про то думаешь? -- Ваше превосходительство, коли есть какие-нибудь документы или',
#  '',
#  '',
#  ' -- Врешь, братец, какие тебе документы',
#  ' На то указы',
#  ' В том-то и сила, чтобы безо всякого права отнять имение',
#  ' Постой однако ж',
#  ' Это имение принадлежало некогда нам, было куплено у какого-то Спицына и продано потом отцу Дубровского',
#  ' Нельзя ли к этому придраться? -- Мудрено, ваше высокопревосходительство; вероятно, сия продажа совершена законным порядком',
#  ' -- Подумай, братец, поищи хорошенько',
#  ' -- Если бы, например, ваше превосходительство могли каким ни есть образом достать от вашего соседа запись или купчую, в силу которой владеет он своим имением, то конечно',
#  '',
#  '',
#  ' -- Понимаю, да вот беда -- у него все бумаги сгорели во время пожара',
#  ' -- Как, ваше превосходительство, бумаги его сгорели! чего ж вам лучше? -- в таком случае извольте действовать по законам, и без всякого сомнения получите ваше совершенное удовольствие',
#  ' -- Ты думаешь? Ну, смотри же']

# %%
tonalnost(text, 150)

# %%
from navec import Navec
from slovnet import Morph
from razdel import tokenize
navec = Navec.load('models//navec_news_v1_1B_250K_300d_100q.tar')
morph = Morph.load('models//slovnet_morph_news_v1.tar')
morph.navec(navec)

def morphing(book):
    m = {'ADJ' : [], 'ADP' : [], 'ADV' : [], 'AUX' : [], 'CCONJ' : [],
        'DET' : [], 'INTJ' :[], 'NOUN' : [], 'NUM' : [], 'PART' : [], 'PRON' : [],
        'PROPN' : [], 'PUNCT' : [], 'SCONJ' : [], 'SYM' : [], 'VERB' : [], 'X' : []}
    tokens = morph([x.text for x in list(tokenize(book))]).tokens
    for token in tokens:
        res = token.pos
        for key in m.keys():
            if key == res:
                m[key].append(1)
            else:
                m[key].append(0)
    plt.plot(moving_average(m['NOUN'], 2000))
    #return m

# %%
morphing(text)
